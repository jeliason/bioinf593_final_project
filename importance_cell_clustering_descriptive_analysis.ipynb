# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
import collections

# %%
DATA_PATH = './data/'
with open(DATA_PATH+'importance_scores_group_prediction.pkl','rb') as f:
    imp_group = pickle.load(f)

# %%
DATA_PATH = './data/'
with open(DATA_PATH+'scores_per_graph.pkl','rb') as f:
    imp_stage = pickle.load(f)

# %%
len(imp_stage)
# Out:
# 140

# %%
scl = imp_stage[0]

# %%
scl
# Out:
#                        cell_type       X       Y  cell_id  graph_id   campp_0  \
# 0                   granulocytes    77.0   589.0        0         0  0.000000
# 1                   granulocytes   106.0   826.0        1         0  0.205527
# 2                   granulocytes   107.0   545.0        2         0  0.012644
# 3                   granulocytes    98.0   564.0        3         0  0.000000
# 4                   granulocytes   217.0   329.0        4         0  0.000000
# ...                          ...     ...     ...      ...       ...       ...
# 1159                   undefined  1686.0   503.0   240084         0  0.000000
# 1160                   undefined  1868.0   553.0   240085         0  0.000000
# 1161  tumor cells / immune cells  1310.0   135.0   246598         0  0.000000
# 1162  immune cells / vasculature  1634.0  1242.0   248395         0  0.063656
# 1163                immune cells  1674.0  1096.0   250548         0  0.000000
#
#        campp_1  campp_2   campp_3  campp_4   campp_5  campp_6   campp_7  \
# 0     0.000000      0.0  0.000000  0.00000  0.086678      0.0  0.000000
# 1     0.076950      0.0  0.000000  0.00000  0.000000      0.0  0.000000
# 2     0.171711      0.0  0.061048  0.00000  0.048164      0.0  0.000000
# 3     0.000000      0.0  0.008977  0.00000  0.079265      0.0  0.000000
# 4     0.000000      0.0  0.000000  0.00000  0.070130      0.0  0.011328
# ...        ...      ...       ...      ...       ...      ...       ...
# 1159  0.000000      0.0  0.013270  0.00000  0.075089      0.0  0.000000
# 1160  0.099012      0.0  0.064703  0.00000  0.012110      0.0  0.000000
# 1161  0.000000      0.0  0.000000  0.03563  0.089043      0.0  0.000000
# 1162  0.137270      0.0  0.069655  0.00000  0.000000      0.0  0.000000
# 1163  0.000000      0.0  0.000000  0.00000  0.049546      0.0  0.000000
#
#        campp_8   campp_9  campp_median  campp_mad
# 0     0.000000  0.000000      0.000000   0.015602
# 1     0.004025  0.060734      0.000000   0.047808
# 2     0.124192  0.095211      0.030404   0.049395
# 3     0.005902  0.000000      0.000000   0.013970
# 4     0.000000  0.000000      0.000000   0.013033
# ...        ...       ...           ...        ...
# 1159  0.022157  0.000000      0.000000   0.015472
# 1160  0.037635  0.026430      0.006055   0.026365
# 1161  0.000000  0.000000      0.000000   0.019948
# 1162  0.135740  0.164500      0.031828   0.057082
# 1163  0.000000  0.000000      0.000000   0.008918
#
# [1164 rows x 17 columns]

# %%
patient_id = 0
for scl in imp_stage:
    scl.rename(columns = {"graph_id":"spot_id"},inplace=True)
    i = scl.spot_id.unique()[0]
    if i % 4 == 0:
        patient_id += 1
    scl['patient_id'] = patient_id
    cp = pt_data.loc[pt_data.loc[:,'Patient'] == patient_id,'Group'].values[0]
    assert(cp == 1 or cp == 2)
    scl['patient_group'] = cp

# %%
scl = imp_stage[32] # look at dataframe for first graph

# %%
scl
# Out:
#               cell_type       X       Y  cell_id  spot_id   campp_0   campp_1  \
# 0          granulocytes   177.0   465.0     9831       32  0.083173  0.234000
# 1          granulocytes   335.0   971.0     9832       32  0.000000  0.000000
# 2          granulocytes   361.0   994.0     9833       32  0.000000  0.000000
# 3          granulocytes   401.0  1209.0     9834       32  0.097634  0.162869
# 4          granulocytes   445.0   389.0     9835       32  0.000000  0.003994
# ...                 ...     ...     ...      ...      ...       ...       ...
# 2693  CD68+ macrophages  1447.0    30.0   255682       32  0.020327  0.116084
# 2694  CD68+ macrophages  1477.0   877.0   255683       32  0.131252  0.388209
# 2695  CD68+ macrophages  1506.0   185.0   255684       32  0.000000  0.026901
# 2696  CD68+ macrophages  1538.0   164.0   255685       32  0.000000  0.026777
# 2697         lymphatics  1298.0   667.0   257001       32  0.000000  0.000000
#
#        campp_2   campp_3   campp_4   campp_5   campp_6   campp_7   campp_8  \
# 0     0.105137  0.204937  0.002782  0.030598  0.005602  0.013096  0.035767
# 1     0.000000  0.000000  0.072118  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.077793  0.000000  0.000000  0.000000  0.000000
# 3     0.086883  0.100857  0.000000  0.105390  0.000000  0.115408  0.059030
# 4     0.000000  0.000000  0.177747  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 2693  0.000000  0.000000  0.136000  0.000000  0.000000  0.000000  0.000000
# 2694  0.215584  0.211326  0.000000  0.151422  0.162578  0.219393  0.209493
# 2695  0.000000  0.000000  0.070699  0.000000  0.000000  0.000000  0.000000
# 2696  0.000000  0.000000  0.083837  0.000000  0.000000  0.000000  0.000000
# 2697  0.000000  0.000000  0.091875  0.000000  0.000000  0.000000  0.000000
#
#        campp_9  campp_median  campp_mad  patient_id  patient_group
# 0     0.008603      0.033182   0.067554           9              2
# 1     0.000000      0.000000   0.012981           9              2
# 2     0.000000      0.000000   0.014003           9              2
# 3     0.000000      0.092258   0.046440           9              2
# 4     0.000000      0.000000   0.031915           9              2
# ...        ...           ...        ...         ...            ...
# 2693  0.000000      0.000000   0.039520           9              2
# 2694  0.164951      0.187222   0.063380           9              2
# 2695  0.000000      0.000000   0.015616           9              2
# 2696  0.000000      0.000000   0.017698           9              2
# 2697  0.000000      0.000000   0.016538           9              2
#
# [2698 rows x 19 columns]

# %%
imp_stage_df = pd.concat(imp_stage)

# %%
imp_stage_df
# Out:
#                        cell_type       X      Y  cell_id  spot_id   campp_0  \
# 0                   granulocytes    77.0  589.0        0        0  0.000000
# 1                   granulocytes   106.0  826.0        1        0  0.205527
# 2                   granulocytes   107.0  545.0        2        0  0.012644
# 3                   granulocytes    98.0  564.0        3        0  0.000000
# 4                   granulocytes   217.0  329.0        4        0  0.000000
# ...                          ...     ...    ...      ...      ...       ...
# 1020  immune cells / vasculature  1760.0  340.0   250545      139  0.000000
# 1021  immune cells / vasculature  1771.0  379.0   250546      139  0.000000
# 1022  immune cells / vasculature  1820.0  534.0   250547      139  0.000000
# 1023                    NK cells   547.0   71.0   253997      139  0.174553
# 1024           CD68+ macrophages  1504.0  835.0   256947      139  0.301723
#
#        campp_1  campp_2   campp_3   campp_4   campp_5   campp_6   campp_7  \
# 0     0.000000      0.0  0.000000  0.000000  0.086678  0.000000  0.000000
# 1     0.076950      0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 2     0.171711      0.0  0.061048  0.000000  0.048164  0.000000  0.000000
# 3     0.000000      0.0  0.008977  0.000000  0.079265  0.000000  0.000000
# 4     0.000000      0.0  0.000000  0.000000  0.070130  0.000000  0.011328
# ...        ...      ...       ...       ...       ...       ...       ...
# 1020  0.000000      0.0  0.000000  0.350962  0.109427  0.009119  0.000000
# 1021  0.000000      0.0  0.000000  0.390879  0.108796  0.009440  0.000000
# 1022  0.000000      0.0  0.000000  0.439668  0.103302  0.010731  0.000000
# 1023  0.000000      0.0  0.000000  0.000000  0.109509  0.000256  0.000000
# 1024  0.000000      0.0  0.000000  0.032971  0.114344  0.000230  0.000000
#
#        campp_8   campp_9  campp_median  campp_mad  patient_id  patient_group
# 0     0.000000  0.000000      0.000000   0.015602           1              1
# 1     0.004025  0.060734      0.000000   0.047808           1              1
# 2     0.124192  0.095211      0.030404   0.049395           1              1
# 3     0.005902  0.000000      0.000000   0.013970           1              1
# 4     0.000000  0.000000      0.000000   0.013033           1              1
# ...        ...       ...           ...        ...         ...            ...
# 1020  0.000000  0.118731      0.000000   0.080530          35              1
# 1021  0.000000  0.121545      0.000000   0.086404          35              1
# 1022  0.000000  0.150292      0.000000   0.096413          35              1
# 1023  0.000000  0.248823      0.000000   0.074588          35              1
# 1024  0.000000  0.051353      0.000115   0.063447          35              1
#
# [258385 rows x 19 columns]

# %%
imp_stage_df.to_csv(DATA_PATH+'importance_scores_stage_prediction.csv')

# %%
scl.attrs
# Out:
# {'pred_0': 3.0,
#  'pred_1': 3.0,
#  'pred_2': 3.0,
#  'pred_3': 3.0,
#  'pred_4': 4.0,
#  'pred_5': 3.0,
#  'pred_6': 3.0,
#  'pred_7': 3.0,
#  'pred_8': 3.0,
#  'pred_9': 3.0,
#  'stage': 3.0}

# %%
stage_preds = {}
for scl in imp_stage:
    i = scl.spot_id.unique()[0]
    stage_preds[i] = scl.attrs
with open(DATA_PATH + 'stage_preds.pkl','wb') as f:
    pickle.dump(stage_preds,f)

# %%
group_preds = {}
for scl in imp_group:
    i = scl.spot_id.unique()[0]
    attrs = scl.attrs
    for k,v in attrs.items():
        if k != 'group':
            attrs[k] = v.item()
    group_preds[i] = attrs
with open(DATA_PATH + 'group_preds.pkl','wb') as f:
    pickle.dump(group_preds,f)

# %%
scl.attrs['pred_0'].item()
# Out:
# 1

# %%
group_preds
# Out:
# {0: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  1: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  2: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  3: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  4: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  5: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  6: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  7: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  8: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  9: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  10: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  11: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  12: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  13: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  14: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  15: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  16: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  17: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  18: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  19: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  20: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  21: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  22: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  23: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  24: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 1,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  25: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  26: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  27: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  28: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  29: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  30: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  31: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  32: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  33: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  34: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  35: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  36: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  37: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  38: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  39: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  40: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  41: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  42: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  43: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  44: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  45: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  46: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  47: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  48: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  49: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  50: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  51: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  52: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  53: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 1,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  54: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  55: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  56: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 1,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  57: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  58: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  59: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  60: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  61: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  62: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  63: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  64: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  65: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  66: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  67: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  68: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  69: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  70: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  71: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  72: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  73: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  74: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  75: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  76: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  77: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  78: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  79: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  80: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  81: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  82: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  83: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  84: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  85: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 1,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  86: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  87: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  88: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  89: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  90: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  91: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  92: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  93: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  94: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  95: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  96: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  97: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  98: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  99: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  100: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  101: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  102: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  103: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  104: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  105: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  106: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  107: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  108: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  109: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  110: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  111: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  112: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  113: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  114: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  115: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  116: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  117: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  118: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  119: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 1,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  120: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  121: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  122: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  123: {'group': 2,
#   'pred_0': 2,
#   'pred_1': 2,
#   'pred_2': 2,
#   'pred_3': 2,
#   'pred_4': 2,
#   'pred_5': 2,
#   'pred_6': 2,
#   'pred_7': 2,
#   'pred_8': 2,
#   'pred_9': 2},
#  124: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  125: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  126: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  127: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  128: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  129: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  130: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  131: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  132: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  133: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  134: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  135: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  136: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  137: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  138: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1},
#  139: {'group': 1,
#   'pred_0': 1,
#   'pred_1': 1,
#   'pred_2': 1,
#   'pred_3': 1,
#   'pred_4': 1,
#   'pred_5': 1,
#   'pred_6': 1,
#   'pred_7': 1,
#   'pred_8': 1,
#   'pred_9': 1}}

# %% [markdown]
# ### Correlation of median and MAD

# %%
import scipy.stats as stats

stats.pearsonr(importance_scores.loc[:,'campp_median'].values,importance_scores.loc[:,'campp_mad'].values)

# double check this
# Out:
# (0.6822224441492671, 0.0)

# %%
scl.loc[:,'campp_median'].values
# Out:
# array([0.13232525, 0.01682023, 0.00907956, ..., 0.05581832, 0.17314517,
#        0.        ], dtype=float32)

# %%
scl.loc[:,'campp_median']
# Out:
# 0       0.132325
# 1       0.016820
# 2       0.009080
# 3       0.217490
# 4       0.029731
#           ...
# 1159    0.009565
# 1160    0.034728
# 1161    0.055818
# 1162    0.173145
# 1163    0.000000
# Name: campp_median, Length: 1164, dtype: float32

# %%
stats.spearmanr(importance_scores.loc[:,'campp_median'].values,importance_scores.loc[:,'campp_mad'].values)
# Out:
# SpearmanrResult(correlation=0.7385660715818451, pvalue=0.0)

# %%
def perm_test(a,b,metric=stats.pearsonr,n=1000,rng=np.random.default_rng(1234)):
    true_metric = metric(a,b)[0]
    perms = []
    for _ in range(n):
        rng.shuffle(a)
        perms.append(metric(a,b)[0])
    q = np.sum(np.sort(perms) <= true_metric) / n
    return true_metric,perms,q

# %%
_,_,q = perm_test(scl.loc[:,'campp_median'].values,scl.loc[:,'campp_mad'].values,n=10000)

# %%
q
# Out:
# 0.6054

# %% [markdown]
# This does not seem to be totally stable. Either way, it does seem like we have homoscedasticity here (no trend in MAD correlated with the median scores) which is good. I guess I also need to check all graphs, technically.

# %% [markdown]
# ### ANOVA of median scores

# %%
from scipy.stats import f_oneway

# %%
f_oneway(*[scl.loc[scl['cell_type'] == cell_type]['campp_median'].values for cell_type in scl['cell_type'].unique()])
# Out:
# F_onewayResult(statistic=38.93901789925754, pvalue=2.2062610198085543e-132)

# %%
samples = [scl.loc[scl['cell_type'] == cell_type]['campp_median'].values for cell_type in scl['cell_type'].unique()]

# %%
from statsmodels.stats.multicomp import (pairwise_tukeyhsd,
                                         MultiComparison)

# %%
res2 = pairwise_tukeyhsd(scl['campp_median'], scl['cell_type'])

# %%
res2.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
res2.plot_simultaneous(comparison_name='tumor cells')
plt.show()
# Out:
# /home/joeleliason/anaconda3/envs/hactnet/lib/python3.7/site-packages/statsmodels/sandbox/stats/multicomp.py:775: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(np.insert(self.groupsunique.astype(str), 0, ''))

# %%
res2.halfwidths
# Out:
# array([0.04208607, 0.18605281, 0.12545434, 0.01755266, 0.03200992,
#        0.01561616, 0.01908708, 0.0325439 , 0.05168635, 0.02977074,
#        0.03059048, 0.18605281, 0.18605281, 0.18605281, 0.01515345,
#        0.01607133, 0.01722108, 0.01512284, 0.0624387 , 0.02977074,
#        0.01901388])

# %%
res2.
# Out:
# array([-2.56089527e-02, -2.07615621e-02,  3.35513454e-03, -3.12921258e-03,
#         1.67908756e-02,  4.39786395e-02,  7.97454032e-03,  5.87013832e-02,
#         1.94241431e-02,  8.39382276e-03,  3.16596966e-02,  1.77064019e-03,
#        -2.56089527e-02,  1.01721480e-02, -1.14418997e-02,  2.02997987e-03,
#         8.49432049e-02,  1.00289012e-01,  1.25405002e-02,  1.26522260e-02,
#         4.84739058e-03,  2.89640872e-02,  2.24797401e-02,  4.23998283e-02,
#         6.95875922e-02,  3.35834930e-02,  8.43103359e-02,  4.50330958e-02,
#         3.40027755e-02,  5.72686493e-02,  2.73795929e-02,  0.00000000e+00,
#         3.57811007e-02,  1.41670530e-02,  2.76389326e-02,  1.10552158e-01,
#         1.25897965e-01,  3.81494529e-02,  3.82611787e-02,  2.41166967e-02,
#         1.76323495e-02,  3.75524377e-02,  6.47402017e-02,  2.87361024e-02,
#         7.94629453e-02,  4.01857052e-02,  2.91553849e-02,  5.24212588e-02,
#         2.25322023e-02, -4.84739058e-03,  3.09337101e-02,  9.31966246e-03,
#         2.27915420e-02,  1.05704767e-01,  1.21050574e-01,  3.33020623e-02,
#         3.34137881e-02, -6.48434712e-03,  1.34357411e-02,  4.06235050e-02,
#         4.61940578e-03,  5.53462486e-02,  1.60690085e-02,  5.03868821e-03,
#         2.83045621e-02, -1.58449436e-03, -2.89640872e-02,  6.81701348e-03,
#        -1.47970342e-02, -1.32515468e-03,  8.15880704e-02,  9.69338777e-02,
#         9.18536563e-03,  9.29709147e-03,  1.99200882e-02,  4.71078521e-02,
#         1.11037529e-02,  6.18305958e-02,  2.25533557e-02,  1.15230353e-02,
#         3.47889092e-02,  4.89985277e-03, -2.24797401e-02,  1.33013606e-02,
#        -8.31268707e-03,  5.15919245e-03,  8.80724175e-02,  1.03418225e-01,
#         1.56697128e-02,  1.57814386e-02,  2.71877639e-02, -8.81633530e-03,
#         4.19105076e-02,  2.63326745e-03, -8.39705287e-03,  1.48688210e-02,
#        -1.50202354e-02, -4.23998283e-02, -6.61872760e-03, -2.82327753e-02,
#        -1.47608958e-02,  6.81523293e-02,  8.34981366e-02, -4.25037546e-03,
#        -4.13864962e-03, -3.60040992e-02,  1.47227436e-02, -2.45544965e-02,
#        -3.55848168e-02, -1.23189429e-02, -4.22079993e-02, -6.95875922e-02,
#        -3.38064915e-02, -5.54205392e-02, -4.19486597e-02,  4.09645654e-02,
#         5.63103727e-02, -3.14381394e-02, -3.13264135e-02,  5.07268429e-02,
#         1.14496028e-02,  4.19282434e-04,  2.36851563e-02, -6.20390014e-03,
#        -3.35834930e-02,  2.19760770e-03, -1.94164400e-02, -5.94456046e-03,
#         7.69686646e-02,  9.23144719e-02,  4.56595985e-03,  4.67768569e-03,
#        -3.92772401e-02, -5.03075604e-02, -2.70416865e-02, -5.69307430e-02,
#        -8.43103359e-02, -4.85292352e-02, -7.01432828e-02, -5.66714033e-02,
#         2.62418217e-02,  4.15876290e-02, -4.61608830e-02, -4.60491572e-02,
#        -1.10303203e-02,  1.22355536e-02, -1.76535029e-02, -4.50330958e-02,
#        -9.25199505e-03, -3.08660427e-02, -1.73941632e-02,  6.55190618e-02,
#         8.08648691e-02, -6.88364290e-03, -6.77191706e-03,  2.32658739e-02,
#        -6.62318257e-03, -3.40027755e-02,  1.77832527e-03, -1.98357224e-02,
#        -6.36384289e-03,  7.65493821e-02,  9.18951894e-02,  4.14667741e-03,
#         4.25840325e-03, -2.98890565e-02, -5.72686493e-02, -2.14875486e-02,
#        -4.31015963e-02, -2.96297168e-02,  5.32835083e-02,  6.86293156e-02,
#        -1.91191965e-02, -1.90074706e-02, -2.73795929e-02,  8.40150784e-03,
#        -1.32125398e-02,  2.59339680e-04,  8.31725647e-02,  9.85183720e-02,
#         1.07698600e-02,  1.08815858e-02,  3.57811007e-02,  1.41670530e-02,
#         2.76389326e-02,  1.10552158e-01,  1.25897965e-01,  3.81494529e-02,
#         3.82611787e-02, -2.16140477e-02, -8.14216816e-03,  7.47710569e-02,
#         9.01168642e-02,  2.36835214e-03,  2.48007798e-03,  1.34718795e-02,
#         9.63851046e-02,  1.11730912e-01,  2.39823998e-02,  2.40941257e-02,
#         8.29132250e-02,  9.82590323e-02,  1.05105203e-02,  1.06222461e-02,
#         1.53458073e-02, -7.24027047e-02, -7.22909789e-02, -8.77485120e-02,
#        -8.76367862e-02,  1.11725841e-04])

# %%
pt_data = pd.read_excel(DATA_PATH+'CRC_TMAs_patient_annotations.xlsx')
# Out:
# /home/joeleliason/anaconda3/envs/hactnet/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   """Entry point for launching an IPython kernel.

# %%
patient_id = 0
# new_scores_per_graph = []
for scl in imp_groupy:
    # scl = scl1.copy()
    i = scl.spot_id.unique()[0]
    if i % 4 == 0:
        patient_id += 1
    scl['patient_id'] = patient_id
    cp = pt_data.loc[pt_data.loc[:,'Patient'] == patient_id,'Group'].values[0]
    assert(cp == 1 or cp == 2)
    scl['patient_group'] = cp
    # new_scores_per_graph.append(scl)

# %%
scl = scores_per_graph[0]

# %%
scl.attrs
# Out:
# {'group': 1,
#  'pred_0': tensor(1),
#  'pred_1': tensor(1),
#  'pred_2': tensor(1),
#  'pred_3': tensor(1),
#  'pred_4': tensor(1),
#  'pred_5': tensor(1),
#  'pred_6': tensor(1),
#  'pred_7': tensor(1),
#  'pred_8': tensor(1),
#  'pred_9': tensor(1)}

# %%
importance_scores = pd.concat(scores_per_graph)

# %%
importance_scores
# Out:
#                        cell_type       X      Y  cell_id  spot_id   campp_0  \
# 0                   granulocytes    77.0  589.0        0        0  0.016950
# 1                   granulocytes   106.0  826.0        1        0  0.014687
# 2                   granulocytes   107.0  545.0        2        0  0.068091
# 3                   granulocytes    98.0  564.0        3        0  0.007142
# 4                   granulocytes   217.0  329.0        4        0  0.252162
# ...                          ...     ...    ...      ...      ...       ...
# 1020  immune cells / vasculature  1760.0  340.0   250545      139  0.028843
# 1021  immune cells / vasculature  1771.0  379.0   250546      139  0.000000
# 1022  immune cells / vasculature  1820.0  534.0   250547      139  0.011755
# 1023                    NK cells   547.0   71.0   253997      139  0.000000
# 1024           CD68+ macrophages  1504.0  835.0   256947      139  0.000000
#
#        campp_1   campp_2   campp_3   campp_4   campp_5   campp_6   campp_7  \
# 0     0.350585  0.000000  0.116528  0.140501  0.017379  0.099837  0.129521
# 1     0.075043  0.240120  0.269666  0.001379  0.047645  0.000000  0.006499
# 2     0.000000  0.000000  0.030736  0.028675  0.017152  0.000000  0.099696
# 3     0.281647  0.000000  0.060714  0.322154  0.054891  0.217566  0.138132
# 4     0.901895  0.414942  0.469559  0.380645  0.344093  0.475564  0.249722
# ...        ...       ...       ...       ...       ...       ...       ...
# 1020  0.000000  0.041830  0.013085  0.096057  0.058998  0.085951  0.000000
# 1021  0.000000  0.000000  0.000000  0.000000  0.085537  0.033606  0.000000
# 1022  0.000000  0.021281  0.000000  0.000000  0.030186  0.217851  0.062268
# 1023  0.004622  0.079945  0.065453  0.023014  0.013056  0.000000  0.000000
# 1024  0.000000  0.047900  0.000000  0.000000  0.068770  0.152838  0.098940
#
#        campp_8   campp_9  campp_median  campp_mad  patient_id  patient_group
# 0     0.024781  0.007914      0.124601   0.076995           1              1
# 1     0.023416  0.148588      0.035362   0.082052           1              1
# 2     0.010412  0.000000      0.078084   0.025059           1              1
# 3     0.020155  0.000000      0.036945   0.103708           1              1
# 4     0.201604  0.044381      0.152361   0.155064           1              1
# ...        ...       ...           ...        ...         ...            ...
# 1020  0.000000  0.040406      0.034624   0.028131          35              1
# 1021  0.000000  0.039697      0.000000   0.022238          35              1
# 1022  0.024682  0.034050      0.022981   0.039941          35              1
# 1023  0.000000  0.077384      0.008839   0.028748          35              1
# 1024  0.033926  0.020443      0.027185   0.039864          35              1
#
# [258385 rows x 19 columns]

# %%
importance_scores.to_csv(DATA_PATH+'importance_scores_group_prediction.csv')

# %%
scl.spot_id.unique()[0]
# Out:
# array([32])

# %% [markdown]
# MAD based on cell type
